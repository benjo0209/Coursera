# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**

# %% [markdown]
# - List popular languages Data Scientists use
# - List popular tools Data Scientists use
# - Create a table
# - Create artyhmetic expressions

# %% [markdown]
# Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1. Python
# 2. R
# 3. SQL
# 4. Java

# %% [markdown]
# Some of the popular tools that Data Scientists use are:

# %% [markdown]
# 1. TensorFlow
# 2. Pandas
# 3. Scipy
# 4. NumPy

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Jupyter Notebooks|
# |Jupyter Labs|
# |VSCode|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
#This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes to hours by diving by 60

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author

# %% [markdown]
# Benjamin Stratton
